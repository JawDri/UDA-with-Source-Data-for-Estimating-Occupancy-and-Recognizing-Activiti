# %% [markdown]
# <a id="section-one"></a>
# ## 1 Import Libraries and download data

# %% [markdown]
# <a id="define-device"></a>
# ### 1.2 Define device

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #OE 2 unbalanced labels

# %%
import pandas as pd
import numpy as np
import random
np.random.seed(2021)

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,1)

  return data


Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=1

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=1

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=1

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:1045]
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:300]
frames = [Data_0, Data_2]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:772]
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:200]
frames = [Data_0, Data_2]
Final_Data_S2 = pd.concat(frames)

Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]
Target_test = Final_Data_S2.iloc[:150,:]

#Source_train = poison_data(Source_train, 0.1)
#Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)

# %% [markdown]
# #OE 3 unbalanced labels

# %%
import pandas as pd
import numpy as np
import random
np.random.seed(2021)

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,2)

  return data
Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=2

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=2

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:1045]
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:300]
Data_3 = Final_Data_S1[Final_Data_S1.labels == 2].iloc[:300]
frames = [Data_0, Data_2, Data_3]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:772]
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:200]
Data_3 = Final_Data_S2[Final_Data_S2.labels == 2].iloc[:200]
frames = [Data_0, Data_2, Data_3]
Final_Data_S2 = pd.concat(frames)

Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]
Target_test = Final_Data_S2.iloc[:150,:]

Source_train = poison_data(Source_train, 0.1)
Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #OE balanced 2 labels

# %%
import pandas as pd
import numpy as np
import random
np.random.seed(2021)

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,1)

  return data

Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=1

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=1

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=1

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[500:,:]
Source_test = Final_Data_S1.iloc[:500,:]

Target_train = Final_Data_S2.iloc[500:,:]
Target_test = Final_Data_S2.iloc[:500,:]

Source_train = poison_data(Source_train, 0.1)
Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #OE balanced 3 labels

# %%
import pandas as pd
import numpy as np
import random
np.random.seed(2021)

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,2)

  return data

Final_Data_S1 = pd.read_csv("/content/drive/MyDrive/Final_Data_S1.csv")
Final_Data_S2 = pd.read_csv("/content/drive/MyDrive/Final_Data_S2.csv")


Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([3.0, 4.0])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([3.0, 4.0])].index,'labels']=2

# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE 

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([0.0])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([1.0])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin([2.0])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([0.0])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([1.0])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin([2.0])].index,'labels']=2

labels_S1 = Final_Data_S1.labels
labels_S2 = Final_Data_S2.labels
Data_S1 = Final_Data_S1.drop(['time', 'labels'], axis= 1)
Data_S2 = Final_Data_S2.drop(['time', 'labels'], axis= 1)

from sklearn.decomposition import PCA
pca = PCA(n_components=9)
principalComponents_S1 = pca.fit_transform(Data_S1)
pca = PCA(n_components=9)
principalComponents_S2 = pca.fit_transform(Data_S2)

sm = SMOTE(random_state=2)
principalComponents_S1, labels_S1 = sm.fit_resample(principalComponents_S1, labels_S1)
principalComponents_S2, labels_S2 = sm.fit_resample(principalComponents_S2, labels_S2)

Final_Data_S1 = pd.DataFrame(principalComponents_S1)
Final_Data_S2 = pd.DataFrame(principalComponents_S2)

Final_Data_S1['labels'] = labels_S1
Final_Data_S2['labels'] = labels_S2


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[500:,:]
Source_test = Final_Data_S1.iloc[:500,:]

Target_train = Final_Data_S2.iloc[500:,:]
Target_test = Final_Data_S2.iloc[:500,:]

Source_train = poison_data(Source_train, 0.1)
Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# #Load Data AR: 3 Activities

# %%
import pandas as pd 
import numpy as np
import random
np.random.seed(2021)
# !wget http://casas.wsu.edu/datasets/hh101.zip
# !wget http://casas.wsu.edu/datasets/hh105.zip
# !unzip '/content/hh105.zip'
# !unzip /content/hh101.zip
# !pip install imbalanced-learn
from imblearn.over_sampling import SMOTE

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,2)
  return data

Final_Data_S1 = pd.read_csv("/content/hh101/hh101.ann.features.csv")
Final_Data_S2 = pd.read_csv("/content/hh105/hh105.ann.features.csv")
Final_Data_S1.rename(columns={"activity": "labels"}, inplace= True)
Final_Data_S2.rename(columns={"activity": "labels"}, inplace= True)

Final_Data_S1 = Final_Data_S1.drop(['lastSensorEventHours', 'lastSensorEventSeconds', 'lastSensorDayOfWeek','lastSensorID'], axis= 1)
Final_Data_S2 = Final_Data_S2.drop(['lastSensorEventHours', 'lastSensorEventSeconds','lastSensorDayOfWeek', 'lastSensorID'], axis= 1)

Final_Data_S1 = Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Breakfast',  'Watch_TV', 'Toilet' ])]
Final_Data_S2 = Final_Data_S2[Final_Data_S2.labels.isin([ 'Cook_Breakfast',  'Watch_TV', 'Toilet' ])]

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Watch_TV'])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Toilet'])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Breakfast'])].index,'labels']=2

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Watch_TV'])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Toilet'])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Breakfast'])].index,'labels']=2



Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:4000]#2000#4000
Data_2 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:2000]#2000
Data_3 = Final_Data_S1[Final_Data_S1.labels == 2].iloc[:2000]#2000
frames = [Data_0, Data_2, Data_3]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:2000]#1000#2000
Data_2 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:1000]#1000
Data_3 = Final_Data_S2[Final_Data_S2.labels == 2].iloc[:1000]#1000
frames = [Data_0, Data_2, Data_3]
Final_Data_S2 = pd.concat(frames)


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)


Source_train = Final_Data_S1.iloc[200:,:]#1000
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]#500
Target_test = Final_Data_S2.iloc[:150,:]


#Source_train = poison_data(Source_train, 0.1)
#Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_test.csv', index=False)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)

# %% [markdown]
# #Load Data AR: 5 Activities

# %%
import pandas as pd 
import numpy as np
import random
np.random.seed(2021)
# !wget http://casas.wsu.edu/datasets/hh101.zip
# !wget http://casas.wsu.edu/datasets/hh105.zip
# !unzip '/content/hh105.zip'
# !unzip /content/hh101.zip

def poison_data(data, rate):
  indx = int(len(data)*rate)
  for i in range(indx):
    data.labels.iloc[i] = random.randint(0,4)
  return data

Final_Data_S1 = pd.read_csv("/content/hh101/hh101.ann.features.csv")
Final_Data_S2 = pd.read_csv("/content/hh105/hh105.ann.features.csv")
Final_Data_S1.rename(columns={"activity": "labels"}, inplace= True)
Final_Data_S2.rename(columns={"activity": "labels"}, inplace= True)

Final_Data_S1 = Final_Data_S1.drop(['lastSensorEventHours', 'lastSensorEventSeconds', 'lastSensorDayOfWeek','lastSensorID'], axis= 1)
Final_Data_S2 = Final_Data_S2.drop(['lastSensorEventHours', 'lastSensorEventSeconds','lastSensorDayOfWeek', 'lastSensorID'], axis= 1)

Final_Data_S1 = Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Dinner', 'Cook_Breakfast', 'Cook_Lunch', 'Watch_TV', 'Toilet' ])]
Final_Data_S2 = Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Dinner', 'Cook_Breakfast', 'Cook_Lunch', 'Watch_TV', 'Toilet' ])]

Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Watch_TV'])].index,'labels']=0
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Lunch'])].index,'labels']=1
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Toilet'])].index,'labels']=2
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Breakfast'])].index,'labels']=3
Final_Data_S1.loc[Final_Data_S1[Final_Data_S1.labels.isin(['Cook_Dinner'])].index,'labels']=4

Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Watch_TV'])].index,'labels']=0
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Lunch'])].index,'labels']=1
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Toilet'])].index,'labels']=2
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Breakfast'])].index,'labels']=3
Final_Data_S2.loc[Final_Data_S2[Final_Data_S2.labels.isin(['Cook_Dinner'])].index,'labels']=4

Data_0 = Final_Data_S1[Final_Data_S1.labels == 0].iloc[:4000]#2000#4000
Data_1 = Final_Data_S1[Final_Data_S1.labels == 1].iloc[:4000]#4000
Data_2 = Final_Data_S1[Final_Data_S1.labels == 2].iloc[:2000]#2000
Data_3 = Final_Data_S1[Final_Data_S1.labels == 3].iloc[:4000]#4000
Data_4 = Final_Data_S1[Final_Data_S1.labels == 4].iloc[:2000]#
frames = [Data_0, Data_1, Data_2, Data_3, Data_4]
Final_Data_S1 = pd.concat(frames)

Data_0 = Final_Data_S2[Final_Data_S2.labels == 0].iloc[:2000]#1000#2000
Data_1 = Final_Data_S2[Final_Data_S2.labels == 1].iloc[:2000]#2000
Data_2 = Final_Data_S2[Final_Data_S2.labels == 2].iloc[:1000]#
Data_3 = Final_Data_S2[Final_Data_S2.labels == 3].iloc[:2000]#2000
Data_4 = Final_Data_S2[Final_Data_S2.labels == 4].iloc[:1000]#
frames = [Data_0, Data_1, Data_2, Data_3, Data_4]
Final_Data_S2 = pd.concat(frames)


Final_Data_S1 = Final_Data_S1.sample(frac = 1)
Final_Data_S2 = Final_Data_S2.sample(frac = 1)

Source_train = Final_Data_S1.iloc[200:,:]#1000#
Source_test = Final_Data_S1.iloc[:200,:]

Target_train = Final_Data_S2.iloc[150:,:]#500#
Target_test = Final_Data_S2.iloc[:150,:]

Source_train = poison_data(Source_train, 0.1)
Target_train = poison_data(Target_train, 0.1)

Source_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_train.csv', index=False)
Source_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Source_test.csv', index=False)
Target_train.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_train.csv', index=False)
Target_test.to_csv('/content/drive/MyDrive/SAFN/code/data/Target_test.csv', index=False)

# %%
import os
os.chdir('/content/drive/MyDrive/SAFN/code')

# %%
# !python train.py
# Out:
# ==========================================
# ==========       CONFIG      =============
# ==========================================
# data_root:
# source:
# target:
# batch_size:32
# shuffle:True
# num_workers:4
# epoch:100
# snapshot:
# lr:0.001
# class_num:2
# extract:True
# weight_L2norm:0.05
# dropout_p:0.5
# task:
# post:-1
# repeat:-1
#
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# >>training  epoch : 1
# 0it [00:00, ?it/s]train.py:93: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   cls_loss = F.nll_loss(F.log_softmax(pred), gt)
# 26it [00:02,  9.48it/s]
# >>training  epoch : 2
# 26it [00:00, 50.08it/s]
# >>training  epoch : 3
# 26it [00:00, 48.41it/s]
# >>training  epoch : 4
# 26it [00:00, 49.58it/s]
# >>training  epoch : 5
# 26it [00:00, 71.21it/s]
# >>training  epoch : 6
# 26it [00:00, 99.84it/s]
# >>training  epoch : 7
# 26it [00:00, 105.54it/s]
# >>training  epoch : 8
# 26it [00:00, 101.63it/s]
# >>training  epoch : 9
# 26it [00:00, 100.17it/s]
# >>training  epoch : 10
# 26it [00:00, 93.34it/s]
# >>training  epoch : 11
# 26it [00:00, 96.06it/s]
# >>training  epoch : 12
# 26it [00:00, 97.82it/s]
# >>training  epoch : 13
# 26it [00:00, 97.91it/s]
# >>training  epoch : 14
# 26it [00:00, 100.83it/s]
# >>training  epoch : 15
# 26it [00:00, 91.51it/s]
# >>training  epoch : 16
# 26it [00:00, 75.50it/s]
# >>training  epoch : 17
# 26it [00:00, 66.52it/s]
# >>training  epoch : 18
# 26it [00:00, 67.21it/s]
# >>training  epoch : 19
# 26it [00:00, 61.22it/s]
# >>training  epoch : 20
# 26it [00:00, 90.27it/s]
# >>training  epoch : 21
# 26it [00:00, 102.28it/s]
# >>training  epoch : 22
# 26it [00:00, 96.76it/s]
# >>training  epoch : 23
# 26it [00:00, 102.50it/s]
# >>training  epoch : 24
# 26it [00:00, 99.46it/s]
# >>training  epoch : 25
# 26it [00:00, 99.16it/s]
# >>training  epoch : 26
# 26it [00:00, 99.32it/s]
# >>training  epoch : 27
# 26it [00:00, 93.01it/s]
# >>training  epoch : 28
# 26it [00:00, 99.35it/s]
# >>training  epoch : 29
# 26it [00:00, 96.92it/s]
# >>training  epoch : 30
# 26it [00:00, 87.56it/s]
# >>training  epoch : 31
# 26it [00:00, 100.64it/s]
# >>training  epoch : 32
# 26it [00:00, 96.17it/s]
# >>training  epoch : 33
# 26it [00:00, 98.35it/s]
# >>training  epoch : 34
# 26it [00:00, 95.08it/s]
# >>training  epoch : 35
# 26it [00:00, 99.47it/s]
# >>training  epoch : 36
# 26it [00:00, 101.10it/s]
# >>training  epoch : 37
# 26it [00:00, 72.72it/s]
# >>training  epoch : 38
# 26it [00:00, 64.52it/s]
# >>training  epoch : 39
# 26it [00:00, 70.59it/s]
# >>training  epoch : 40
# 26it [00:00, 64.76it/s]
# >>training  epoch : 41
# 26it [00:00, 98.84it/s]
# >>training  epoch : 42
# 26it [00:00, 97.89it/s]
# >>training  epoch : 43
# 26it [00:00, 99.98it/s]
# >>training  epoch : 44
# 26it [00:00, 96.75it/s]
# >>training  epoch : 45
# 26it [00:00, 99.44it/s]
# >>training  epoch : 46
# 26it [00:00, 97.62it/s]
# >>training  epoch : 47
# 26it [00:00, 100.59it/s]
# >>training  epoch : 48
# 26it [00:00, 94.26it/s]
# >>training  epoch : 49
# 26it [00:00, 90.23it/s]
# >>training  epoch : 50
# 26it [00:00, 99.04it/s]
# >>training  epoch : 51
# 26it [00:00, 96.71it/s]
# >>training  epoch : 52
# 26it [00:00, 103.40it/s]
# >>training  epoch : 53
# 26it [00:00, 97.16it/s]
# >>training  epoch : 54
# 26it [00:00, 100.25it/s]
# >>training  epoch : 55
# 26it [00:00, 95.74it/s]
# >>training  epoch : 56
# 26it [00:00, 96.37it/s]
# >>training  epoch : 57
# 26it [00:00, 68.07it/s]
# >>training  epoch : 58
# 26it [00:00, 67.15it/s]
# >>training  epoch : 59
# 26it [00:00, 65.65it/s]
# >>training  epoch : 60
# 26it [00:00, 64.08it/s]
# >>training  epoch : 61
# 26it [00:00, 101.50it/s]
# >>training  epoch : 62
# 26it [00:00, 101.18it/s]
# >>training  epoch : 63
# 26it [00:00, 98.06it/s]
# >>training  epoch : 64
# 26it [00:00, 95.52it/s]
# >>training  epoch : 65
# 26it [00:00, 97.54it/s]
# >>training  epoch : 66
# 26it [00:00, 99.82it/s]
# >>training  epoch : 67
# 26it [00:00, 99.57it/s]
# >>training  epoch : 68
# 26it [00:00, 91.77it/s]
# >>training  epoch : 69
# 26it [00:00, 95.38it/s]
# >>training  epoch : 70
# 26it [00:00, 96.90it/s]
# >>training  epoch : 71
# 26it [00:00, 96.58it/s]
# >>training  epoch : 72
# 26it [00:00, 105.03it/s]
# >>training  epoch : 73
# 26it [00:00, 105.02it/s]
# >>training  epoch : 74
# 26it [00:00, 105.04it/s]
# >>training  epoch : 75
# 26it [00:00, 97.90it/s]
# >>training  epoch : 76
# 26it [00:00, 99.82it/s]
# >>training  epoch : 77
# 26it [00:00, 98.56it/s]
# >>training  epoch : 78
# 26it [00:00, 73.36it/s]
# >>training  epoch : 79
# 26it [00:00, 71.43it/s]
# >>training  epoch : 80
# 26it [00:00, 71.63it/s]
# >>training  epoch : 81
# 26it [00:00, 69.90it/s]
# >>training  epoch : 82
# 26it [00:00, 101.75it/s]
# >>training  epoch : 83
# 26it [00:00, 102.26it/s]
# >>training  epoch : 84
# 26it [00:00, 101.19it/s]
# >>training  epoch : 85
# 26it [00:00, 100.47it/s]
# >>training  epoch : 86
# 26it [00:00, 102.74it/s]
# >>training  epoch : 87
# 26it [00:00, 100.56it/s]
# >>training  epoch : 88
# 26it [00:00, 101.76it/s]
# >>training  epoch : 89
# 26it [00:00, 95.95it/s]
# >>training  epoch : 90
# 26it [00:00, 104.52it/s]
# >>training  epoch : 91
# 26it [00:00, 98.51it/s]
# >>training  epoch : 92
# 26it [00:00, 96.01it/s]
# >>training  epoch : 93
# 26it [00:00, 98.41it/s]
# >>training  epoch : 94
# 26it [00:00, 104.00it/s]
# >>training  epoch : 95
# 26it [00:00, 92.66it/s]
# >>training  epoch : 96
# 26it [00:00, 100.10it/s]
# >>training  epoch : 97
# 26it [00:00, 99.01it/s]
# >>training  epoch : 98
# 26it [00:00, 101.05it/s]
# >>training  epoch : 99
# 26it [00:00, 74.25it/s]
# >>training  epoch : 100
# 26it [00:00, 64.30it/s]

# %%
# !python train_ent.py
# Out:
# ==========================================
# ==========       CONFIG      =============
# ==========================================
# data_root:
# source:
# target:
# batch_size:32
# shuffle:True
# num_workers:4
# epoch:100
# snapshot:
# lr:0.001
# class_num:2
# extract:True
# weight_L2norm:0.05
# weight_entropy:0.1
# dropout_p:0.5
# task:None
# post:-1
# repeat:-1
#
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# >>training None epoch : 1
# 0it [00:00, ?it/s]train_ent.py:94: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   cls_loss = F.nll_loss(F.log_softmax(pred), gt)
# train_ent.py:148: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   t_prob = F.softmax(t_logit)
# 1it [00:00,  1.56it/s]cls_loss: 0.6896, entropy_loss: 0.0693
# cls_loss: 0.6794, entropy_loss: 0.0693
# cls_loss: 0.6557, entropy_loss: 0.0692
# 15it [00:00, 26.48it/s]cls_loss: 0.6615, entropy_loss: 0.0690
# cls_loss: 0.6284, entropy_loss: 0.0685
# 26it [00:00, 29.68it/s]
# >>training None epoch : 2
# 0it [00:00, ?it/s]cls_loss: 0.6291, entropy_loss: 0.0680
# cls_loss: 0.6039, entropy_loss: 0.0675
# 13it [00:00, 122.06it/s]cls_loss: 0.5644, entropy_loss: 0.0671
# cls_loss: 0.5047, entropy_loss: 0.0660
# cls_loss: 0.5287, entropy_loss: 0.0665
# 26it [00:00, 98.95it/s]
# >>training None epoch : 3
# 0it [00:00, ?it/s]cls_loss: 0.5030, entropy_loss: 0.0645
# cls_loss: 0.5174, entropy_loss: 0.0644
# 12it [00:00, 116.18it/s]cls_loss: 0.5947, entropy_loss: 0.0621
# cls_loss: 0.5467, entropy_loss: 0.0621
# cls_loss: 0.5197, entropy_loss: 0.0616
# 26it [00:00, 95.27it/s]
# cls_loss: 0.0641, entropy_loss: 0.0100
# cls_loss: 0.1990, entropy_loss: 0.0101
# 26it [00:00, 91.27it/s]
# >>training None epoch : 97
# 0it [00:00, ?it/s]cls_loss: 0.0651, entropy_loss: 0.0064
# cls_loss: 0.1679, entropy_loss: 0.0126
# 12it [00:00, 115.47it/s]cls_loss: 0.0339, entropy_loss: 0.0043
# cls_loss: 0.1064, entropy_loss: 0.0113
# cls_loss: 0.0698, entropy_loss: 0.0072
# 26it [00:00, 93.58it/s]
# >>training None epoch : 98
# 0it [00:00, ?it/s]cls_loss: 0.0239, entropy_loss: 0.0079
# cls_loss: 0.0627, entropy_loss: 0.0073
# 12it [00:00, 117.06it/s]cls_loss: 0.2032, entropy_loss: 0.0121
# cls_loss: 0.0716, entropy_loss: 0.0085
# cls_loss: 0.2034, entropy_loss: 0.0068
# 26it [00:00, 93.81it/s]
# >>training None epoch : 99
# 0it [00:00, ?it/s]cls_loss: 0.0366, entropy_loss: 0.0100
# cls_loss: 0.0280, entropy_loss: 0.0132
# 13it [00:00, 123.14it/s]cls_loss: 0.0757, entropy_loss: 0.0119
# cls_loss: 0.0547, entropy_loss: 0.0071
# cls_loss: 0.1052, entropy_loss: 0.0146
# 26it [00:00, 92.77it/s]
# >>training None epoch : 100
# 0it [00:00, ?it/s]cls_loss: 0.4453, entropy_loss: 0.0089
# cls_loss: 0.1795, entropy_loss: 0.0112
# 12it [00:00, 119.94it/s]cls_loss: 0.0218, entropy_loss: 0.0115
# cls_loss: 0.0669, entropy_loss: 0.0105
# cls_loss: 0.0153, entropy_loss: 0.0088
# 26it [00:00, 92.75it/s]

# %%
# !python eval.py
# Out:
# ==========================================
# ==========       CONFIG      =============
# ==========================================
# data_root:
# target:
# batch_size:32
# shuffle:False
# num_workers:4
# snapshot:
# epoch:100
# result:
# class_num:2
# extract:False
# dropout_p:0.5
# task:None
# post:-1
# repeat:-1
#
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# eval.py:101: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
# Epoch 50: 0.8666666666666667
#
# (50) F1-Score. v 0.8692
#
# (50) F1-Score-labels. v  ['0.9123', '0.7222']
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# eval.py:101: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
# Epoch 60: 0.8733333333333333
#
# (60) F1-Score. v 0.8763
#
# (60) F1-Score-labels. v  ['0.9163', '0.7397']
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# eval.py:101: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
# Epoch 70: 0.8733333333333333
#
# (70) F1-Score. v 0.8763
#
# (70) F1-Score-labels. v  ['0.9163', '0.7397']
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# eval.py:101: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
# Epoch 80: 0.88
#
# (80) F1-Score. v 0.8833
#
# (80) F1-Score-labels. v  ['0.9204', '0.7568']
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# eval.py:101: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
# Epoch 90: 0.8666666666666667
#
# (90) F1-Score. v 0.8692
#
# (90) F1-Score-labels. v  ['0.9123', '0.7222']
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# eval.py:101: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
# Epoch 100: 0.8733333333333333
#
# (100) F1-Score. v 0.8763
#
# (100) F1-Score-labels. v  ['0.9163', '0.7397']
